# %%
# !git clone https://github.com/leimao/Voice-Converter-CycleGAN
# %cd Voice-Converter-CycleGAN

# %tensorflow_version 2.x
# !pip uninstall -y tensorflow

# !pip install Numpy==1.14
# !pip install TensorFlow==1.15
# !pip install ProgressBar2==3.37.1
# !pip uninstall -y librosa
# !pip install LibROSA==0.6
# !pip install FFmpeg==4.0
# !pip install PyWorld
# !pip uninstall -y numba
# !pip install numba==0.48
# !pipu uninstall -y resampy
# !pip install resampy==0.3.1
# !pip uninstall -y kapre
# !pip install kapre==0.1.7

# %%
# %cp -a /content/drive/MyDrive/SQILSOFT/CycleGUN/Voice-Converter-CycleGAN/data .

# %%
# !python train.py --train_A_dir ./data/gerasimov --train_B_dir ./data/ermilov --model_dir ./model/gerasimov_ermilov --model_name gerasimov_ermilov.ckpt --random_seed 0 --validation_A_dir ./data/evaluation_all/gerasimov --validation_B_dir ./data/evaluation_all/ermilov --output_dir ./validation_output --tensorboard_log_dir ./log
# !python train.py --train_A_dir ./data/random_guy --train_B_dir ./data/kostya --model_dir ./model/rg_kostya --model_name rg_kostya.ckpt --random_seed 0 --validation_A_dir ./data/evaluation_all/random_guy --validation_B_dir ./data/evaluation_all/kostya --output_dir ./validation_output --tensorboard_log_dir ./log
# Out:
# Preprocessing Data...
# Log Pitch A
# Mean: 4.652271, Std: 0.194088
# Log Pitch B
# Mean: 5.014023, Std: 0.281232
# Input data fixed.
# Preprocessing Done.
# Time Elapsed for Data Preprocessing: 00:00:05
# WARNING:tensorflow:From /content/Voice-Converter-CycleGAN/model.py:35: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/Voice-Converter-CycleGAN/module.py:154: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/Voice-Converter-CycleGAN/module.py:40: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# ...

# %%
# !python convert.py --model_dir ./model/rg_km --model_name rg_km.ckpt --data_dir ./data/evaluation_all/kostya_machine_texts --conversion_direction A2B --output_dir ./converted_voices
